# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


# Download historical data for a stock
gamestop_stock = yf.Ticker("GME")
gme_data = gamestop_stock.history(period="max")
gme_revenue = gamestop_stock.revenue_estimate

gme_data.reset_index(inplace=True)

print(gamestop_stock.dividends)
gamestop_stock.earnings_estimate.plot()
plt.xlabel("Gamestop Data")
plt.show()
# Display the downloaded data
#gme_revenue.tail()


print("---------------------------------")

#Download historical data for a stock
tesla_stock = yf.Ticker("TSLA")
tsla_data = tesla_stock.history(period="max")
tsla_revenue = tesla_stock.revenue_estimate

tsla_data.reset_index(inplace=True)

#print(tesla_stock.calendar)
tesla_stock.earnings_estimate.plot()
plt.xlabel("Tesla, Inc Data")
plt.show()
